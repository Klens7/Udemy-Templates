# %% [markdown]
# ## Pandas built in data visualization

# %%
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
# import this for better styling

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# for creating a histogram

df1['A'].hist()   # can add bins=30 as arguement
# Out:
# <Axes: >

# %%
# import seaborn to make it look like a seaborn plot

import seaborn as sns

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <Axes: >

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# area plot with timeseries data

df2.plot.area(alpha = 0.8)  # alpha for transparency
# Out:
# <Axes: >

# %%
# bar plot
# takes index value as category

df2.plot.bar()  # can add stacked = True  arguement
# Out:
# <Axes: >

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# line plots
# for our timeseries data

df1.plot.line(x=df1.index , y='B')    
# have to specifiy x and y
# x is our df1 index and y is passed as string
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 4
#       1 # line plots
#       2 # for our timeseries data
# ----> 4 df1.plot.line(x=df1.index , y='A')
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\plotting\_core.py:1069, in PlotAccessor.line(self, x, y, **kwargs)
#    1004 @Appender(
#    1005     """
#    1006     See Also
#    (...)
#    1061 @Appender(_bar_or_line_doc)
#    1062 def line(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1063     """
#    1064     Plot Series or DataFrame as lines.
#    1065
#    1066     This function is useful to plot lines using DataFrame's values
#    1067     as coordinates.
#    1068     """
# -> 1069     return self(kind="line", x=x, y=y, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\plotting\_core.py:965, in PlotAccessor.__call__(self, *args, **kwargs)
# ...

# %%
df1.plot.line(x=df1.index,y='A',figsize=(12,3),lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df1.plot.line(x=df1.index,y='b',figsize=(12,3),lw=1)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\plotting\_core.py:1069, in PlotAccessor.line(self, x, y, **kwargs)
#    1004 @Appender(
#    1005     """
#    1006     See Also
#    (...)
#    1061 @Appender(_bar_or_line_doc)
#    1062 def line(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1063     """
#    1064     Plot Series or DataFrame as lines.
#    1065
#    1066     This function is useful to plot lines using DataFrame's values
#    1067     as coordinates.
#    1068     """
# -> 1069     return self(kind="line", x=x, y=y, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\plotting\_core.py:965, in PlotAccessor.__call__(self, *args, **kwargs)
# ...

# %%
# scatterplot

df1.plot.scatter(x='A', y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# same as above but based off color

###    df1.plot.scatter(x='A', y='B', c = 'C')

# or pass in own colormap

df1.plot.scatter(x='A', y='B', c = 'C',cmap = 'coolwarm')

# can pass in datafram column as arguemnt on end  s=df1['C']*100
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2['a'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df2['a']
# Out:
# 0    0.039762
# 1    0.937288
# 2    0.780504
# 3    0.672717
# 4    0.053829
# 5    0.286043
# 6    0.430436
# 7    0.312296
# 8    0.187765
# 9    0.908162
# Name: a, dtype: float64

# %%
# off all columns in dataframe

df2.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
## scatterplot from notebook

###    df3.plot.scatter(x='a',y='b', s=50, c='red', figsize=(12,3))

# %%
## Creating a figure with the legened outside
## first 30 rows, grabbed with slice notation

#  f = plt.figure()
#  df3.ix[0:30].plot.area(alpha=0.4)
#  plt.legend(loc='center left', bbox_to_anchor=(1.0,0.5))
#  plt.show()

# %% [markdown]
# ## Plotly and Cufflinks

# %% [markdown]
# Plotly is an interactive visualization library
# Cufflinks connects plotly with pandas
# -need to install them
# ##### pip install them at command line
# they have websites available with information on them
#
# plotly is a company, they make money hosting the dashboards
# library to host it is free though
#
# cufflinks connects plotly to pandas

# %%
import chart_studio.plotly as py

# %%
import cufflinks as cf

# %%
## open source library offline

from plotly.offline import download_plotlyjs,init_notebook_mode, plot, iplot

# %%
# this will connect the javascript to your notebook

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# run this as method
# allows us to use cufflinks offline


cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# creating a dataframe

df = pd.DataFrame(np.random.randn(100,4), columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -0.551869  0.588691  0.636692  0.730507
# 1 -0.979785  0.818310  0.898591  0.049089
# 2  0.316615 -0.721577  0.673425 -0.299951
# 3  0.334813  0.875180  1.221470 -0.001659
# 4  1.174419 -1.759777 -1.504830 -0.456840

# %%
# creating another dataframe with a dictionary
# used for barplot later

df2 = pd.DataFrame({'Category':['A','B','C'], 'Values': [32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
# %matplotlib inline

# %%
# iplot  makes it interactive


df.iplot()
# Out:
# <div>                            <div id="3d77ab37-aed5-4e78-8cd3-08345770e664" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
## for scatter iplot
# by defualt plotly will makes lines connect
# so do mode='markers'
# can pass in size=20 for bigger points

df.iplot(kind='scatter',x='A',y='B',mode='markers')
# Out:
# <div>                            <div id="b897e905-6a76-412b-bb86-f2b09664c7b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# bar plot with plotly
# with df2 dataframe

df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>                            <div id="22fe4fab-28b4-43a1-bbc1-346e08572628" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# count the instances of each column
# add in aggreageate function or groupby function
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="6c38b7a3-6c1e-44a0-a18a-0a3422a49afb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# box plot

df.iplot(kind='box')
# Out:
# <div>                            <div id="3a25d3e7-642a-4190-840e-235ee9a1ffc4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# 3d surfact plot
# lets make a new dataframe

df3 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[10,20,30,20,1],'z':[500,400,300,200,100]})

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="00230c1d-b11f-4899-bd33-7d6f18002556" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind='hist',bins=25)
# Out:
# <div>                            <div id="98ae6507-a436-46eb-a7fc-60a31dcd234c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# spread type to compare two stocks

df[['A','B']].iplot(kind='spread')
# Out:
# C:\Users\D8ISU4A\AppData\Local\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# C:\Users\D8ISU4A\AppData\Local\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="9a3bc02b-06b6-4028-9b9a-b53f8653796a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# bubble plot, similar to scatter plot but size changes
# world gdp compared to population, etc

df.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>                            <div id="0027eb4f-c167-4ff3-9db3-831c57436d62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
## scatter matrix

# this may crash python kernal if we have a lot of data

df.scatter_matrix()
# Out:
# <div>                            <div id="a32ae0de-9314-4eee-b78e-853be950e6cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
### check out internet for cufflinks cool plots and charts

# %% [markdown]
# ## Introduction to Geographical Plotting

# %% [markdown]
# Geographical plotting is normally challenging due to various formats the data can come in
#
# we will be focused on Plotly - interactive capabilites
#
# Matplotlib also has basemap extension

# %% [markdown]
# ##### Choropleth Maps

# %%
# imports and everything to be working offline

import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
# set up everything so that the figures show up in the notebook

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd

# %% [markdown]
# Now we need to begin to build our data dictionary. Easiest way to do this is use the dict() function
#
# type ='choropleth
# locations=list of states
# locationmode='USA-states'
# colorscale=
#
# Either a predefined string:
#
# 'pairs'  'Greys' 'Greens'  'Blurred'    'Hot'  'Picnic'

# %%
# dict to cast a list to a dictionary

data = dict(type = 'choropleth', 
            # state abbrevation codes
            locations = ['AZ', 'CA', 'NY'],
            
            # to let plotly know its US, can go down to county level
            locationmode = 'USA-states',
            colorscale= 'Jet',
            
            # text is what hovers over the locations, index sequence as above states
            text=['text1', 'text2', 'text3'],
            
            # z is values in the color scale
            z = [1.0,2.0,3.0],
            
            # dictionary of key title and whatever color bar title is
            colorbar= {'title':'Colorbar Title'})

# %%
data
# Out:
# {'type': 'choropleth',
#  'locations': ['AZ', 'CA', 'NY'],
#  'locationmode': 'USA-states',
#  'colorscale': 'Jet',
#  'text': ['text1', 'text2', 'text3'],
#  'z': [1.0, 2.0, 3.0],
#  'colorbar': {'title': 'Colorbar Title'}}

# %%
# then create the layout we need
# dict to cast a list to a dictionary
# nested dictionary

layout = dict(geo = {'scope':'usa'})

# %%
choromap = go.Figure(data = [data],layout=layout)

# %%
iplot(choromap)
# Out:
# <div>                            <div id="4f31cc3f-c238-49ca-a80c-930095d0a85d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f31cc3f-c238-49ca-a80c-930095d0a85d")) {                    Plotly.newPlot(                        "4f31cc3f-c238-49ca-a80c-930095d0a85d",                        [{"colorbar":{"title":{"text":"Colorbar Title"}},"colorscale":[[0.0,"rgb(0,0,131)"],[0.2,"rgb(0,60,170)"],[0.4,"rgb(5,255,255)"],[0.6,"rgb(255,255,0)"],[0.8,"rgb(250,0,0)"],[1.0,"rgb(128,0,0)"]],"locationmode":"USA-states","locations":["AZ","CA","NY"],"text":["text1","text2","text3"],"z":[1.0,2.0,3.0],"type":"choropleth"}],                        {"geo":{"scope":"usa"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fi
# ...

# %% [markdown]
# ### Arriculture Data Graph

# %%
df = pd.read_csv('2011_US_AGRI_Exports')

# %%
df.head()
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton  \
# 0          14.33  34.9   70.0   317.61
# ...

# %%
## data variable and layout variable needed, like above

data = dict(type='choropleth',
           colorscale='ylorbr',
            locations = df['code'],
            locationmode = 'USA-states',
            z = df['total exports'],
            text = df['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width=2)), # can do 12,12,12 and width = 4 for dark borders 
            colorbar = {'title': 'Millions USD'}
            
           )

# %%
layout = dict(title = '2011 US Argriculture Exports by State',
              geo = dict(scope='usa',showlakes = True, lakecolor='rgb(85,173,240)'))

# %%
layout
# Out:
# {'title': '2011 US Argriculture Exports by State',
#  'geo': {'scope': 'usa', 'showlakes': True, 'lakecolor': 'rgb(85,173,240)'}}

# %%
choromap2 = go.Figure(data = [data],layout=layout)

# %%
iplot(choromap2)
# Out:
# <div>                            <div id="e7b0631c-edd6-4899-a77a-790224a95cf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7b0631c-edd6-4899-a77a-790224a95cf9")) {                    Plotly.newPlot(                        "e7b0631c-edd6-4899-a77a-790224a95cf9",                        [{"colorbar":{"title":{"text":"Millions USD"}},"colorscale":[[0.0,"rgb(255,255,229)"],[0.125,"rgb(255,247,188)"],[0.25,"rgb(254,227,145)"],[0.375,"rgb(254,196,79)"],[0.5,"rgb(254,153,41)"],[0.625,"rgb(236,112,20)"],[0.75,"rgb(204,76,2)"],[0.875,"rgb(153,52,4)"],[1.0,"rgb(102,37,6)"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","N
# ...
